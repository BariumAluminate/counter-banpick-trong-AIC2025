# %%
# %matplotlib inline
import numpy as np
import pandas as pd
from datascience import make_array
from datascience import Table
import datascience as ds
import matplotlib.pyplot as plt

# %%
order = make_array(
    'BBan 1', 'Rban 1', 'BBan 2', 'Rban 2',
    'B1',
    'R1', 'R2',
    'B2', 'B3',
    'R3',
    'BBan 3', 'Rban 3','BBan 4', 'Rban 4',
    'R4',
    'B4', 'B5',
    'R5'
)

counter_slot = make_array(
     'B1',
     'R1', 'R2',
     'B2', 'B3',
     'R3',
     'BBan 3', 'Rban 3','BBan 4', 'Rban 4',
     'R4',
     'B4', 'B5',
     'R5'
)

# %%
def find_in_table(tbl, name):
    lb = tbl.labels
    ans = Table()
    for i in lb:
        ans = ans.with_column(i, make_array())
    for lb in order:
        temp = tbl.where(lb, name)
        ans.append(temp)
    return ans

# %%
RoV_2026 = Table().read_table('ROVsummer2026.csv')
RoV_2026
# Out:
# STT  | Blue team | Red team | BBan 1   | BBan 2   | BBan 3     | BBan 4     | B1        | B2       | B3      | B4         | B5      | Rban 1    | Rban 2    | Rban 3     | Rban 4     | R1      | R2     | R3     | R4     | R5       | Time  | Win
# 1    | FS        | GJC      | Annette  | Elandorr | Qi         | Florentino | Rouie     | Hayate   | Billow  | Skud       | Toro    | Sinestria | Zata      | Mganga     | Marja      | Y'bneth | Keera  | Lorion | Wisp   | Murad    | 11:58 | FS
# 2    | GJC       | FS       | Elandorr | Zata     | Tachi      | Keera      | Sinestria | Elsu     | Iggy    | Thane      | Marja   | Rouie     | Enzo      | Skud       | Maloch     | Mganga  | Stuart | Dolia  | Taara  | Zephys   | 18:42 | FS
# 3    | FS        | GJC      | Rouie    | Zata     | Kahlii     | Dolia      | Annette   | Murad    | Elsu    | Aya        | Rickter | Sinestria | Elandorr  | Florentino | Marja      | Capheny | Tachi  | Qi     | Taara  | Yue      | 16:55 | FS
# 4    | SLX       | BAC      | Elandorr | Enzo     | Teemee     | Annette    | Zata      | Edras    | Dolia   | Fennik     | Marja   | Valhein   | Stuart    | Qi         | Capheny    | Hayate  | Tachi  | Murad  | Mganga | Toro     | 12:50 | SLX
# 5    | SLX       | BAC      | Zata     | Marja    | Florentino | Edras      | Yb'neth   | Billow   | Valhein | Biron      | Natalya | Sinestria | Tachi     | Mganga     | Iggy       | Enzo    | Wisp   | Lorion | Skud   | Elandorr | 18:45 | BAC
# 6    | BAC       | SLX      | Murad    | Lorion   | Enzo       | Ignis      | Rouie     | Marja    | Yb'neth | Elsu       | Airi    | Zata      | Sinestria | Florentino | Keera      | Tachi   | Stuart | Qi     | Heino  | Teemee   | 17:16 | BAC
# 7    | SLX       | BAC      | Zata     | Valhein  | Aya        | Dolia      | Iggy      | Elsu     | Zephys  | Florentino | Annette | Sinestria | Rouie     | Skud       | Toro       | Capheny | Keera  | Taara  | Teemee | Tulen    | 14:48 | SLX
# 8    | SLX       | BAC      | Zata     | Valhein  | Stuart     | Maloch     | Lorion    | Elandorr | Toro    | Airi       | Volkath | Rouie     | Sinestria | Skud       | Murad      | Iggy    | Billow | Dolia  | Erin   | Rickter  | 10:00 | SLX
# 9    | BRU       | EA       | Billow   | Enzo     | Florentino | Elandorr   | Tachi     | Capheny  | Annette | Murad      | Thane   | Sinestria | Valhein   | Teemee     | Toro       | Dolia   | Zata   | Elsu   | Biron  | Veres    | 24:33 | BRU
# 10   | EA        | BRU      | Zata     | Valhein  | Yue        | Lorion     | Elandorr  | Yb'neth  | Iggy    | Tachi      | Skud    | Rouie     | Sinestria | Marja      | Florentino | Elsu    | Zephys | Gildur | Ignis  | Edras    | 20:23 | BRU
# ... (26 rows omitted)

# %%
ac = find_in_table(RoV_2026, 'Marja').sort('STT')
ac
# Out:
# STT  | Blue team | Red team | BBan 1   | BBan 2   | BBan 3     | BBan 4     | B1        | B2      | B3      | B4     | B5      | Rban 1    | Rban 2    | Rban 3     | Rban 4     | R1      | R2     | R3      | R4      | R5       | Time  | Win
# 1    | FS        | GJC      | Annette  | Elandorr | Qi         | Florentino | Rouie     | Hayate  | Billow  | Skud   | Toro    | Sinestria | Zata      | Mganga     | Marja      | Y'bneth | Keera  | Lorion  | Wisp    | Murad    | 11:58 | FS
# 2    | GJC       | FS       | Elandorr | Zata     | Tachi      | Keera      | Sinestria | Elsu    | Iggy    | Thane  | Marja   | Rouie     | Enzo      | Skud       | Maloch     | Mganga  | Stuart | Dolia   | Taara   | Zephys   | 18:42 | FS
# 3    | FS        | GJC      | Rouie    | Zata     | Kahlii     | Dolia      | Annette   | Murad   | Elsu    | Aya    | Rickter | Sinestria | Elandorr  | Florentino | Marja      | Capheny | Tachi  | Qi      | Taara   | Yue      | 16:55 | FS
# 4    | SLX       | BAC      | Elandorr | Enzo     | Teemee     | Annette    | Zata      | Edras   | Dolia   | Fennik | Marja   | Valhein   | Stuart    | Qi         | Capheny    | Hayate  | Tachi  | Murad   | Mganga  | Toro     | 12:50 | SLX
# 5    | SLX       | BAC      | Zata     | Marja    | Florentino | Edras      | Yb'neth   | Billow  | Valhein | Biron  | Natalya | Sinestria | Tachi     | Mganga     | Iggy       | Enzo    | Wisp   | Lorion  | Skud    | Elandorr | 18:45 | BAC
# 6    | BAC       | SLX      | Murad    | Lorion   | Enzo       | Ignis      | Rouie     | Marja   | Yb'neth | Elsu   | Airi    | Zata      | Sinestria | Florentino | Keera      | Tachi   | Stuart | Qi      | Heino   | Teemee   | 17:16 | BAC
# 10   | EA        | BRU      | Zata     | Valhein  | Yue        | Lorion     | Elandorr  | Yb'neth | Iggy    | Tachi  | Skud    | Rouie     | Sinestria | Marja      | Florentino | Elsu    | Zephys | Gildur  | Ignis   | Edras    | 20:23 | BRU
# 11   | BRU       | EA       | Billow   | Lorion   | Enzo       | Krizzix    | Sinestria | Marja   | Mganga  | Hayate | Dolia   | Zata      | Rouie     | Toro       | Yb'neth    | Stuart  | Keera  | Qi      | Teemee  | Yue      | 12:10 | BRU
# 12   | HD        | BAC      | Dolia    | Elandorr | Marja      | Stuart     | Rouie     | Edras   | Teemee  | Hayate | Skud    | Sinestria | Billow    | Florentino | Elsu       | Lorion  | Tachi  | Yb'neth | Wisp    | Airi     | 16:43 | BAC
# 14   | BAC       | HD       | Elandorr | Lorion   | Florentino | Murad      | Fennik    | Volkath | Rouie   | Skud   | Enzo    | Marja     | Sinestria | Hayate     | Stuart     | Ignis   | Billow | Yb'neth | Capheny | Airi     | 8:05  | BAC
# ... (16 rows omitted)

# %%
def counter_statistic(tbl : Table, name) :
    ans = Table().with_columns(
        'Name', make_array(),
        'count', make_array()
    )
    for i in range(len(counter_slot)):
        a = counter_slot[i]
        temp_tbl = tbl.where(counter_slot[i], name)
        for j in range(i + 1, len(counter_slot)):
            b = counter_slot[j]
            if b[0] == a[0]:
                continue
            temp = temp_tbl.group(counter_slot[j])
            temp.relabel(counter_slot[j], 'Name')
            ans.append(temp)
        ans = ans.group('Name', sum)
        ans.relabel('count sum', 'count')
    ans = ans.sort('count', descending=True)
    return ans
c = counter_statistic(ac, 'Marja')
c
# Out:
# Name   | count
# Qi     | 6
# Skud   | 5
# Ryoma  | 4
# Teemee | 4
# Toro   | 4
# Wisp   | 4
# Billow | 3
# Iggy   | 3
# Lorion | 3
# Stuart | 3
# ... (29 rows omitted)

# %%
AIC2025 = Table().read_table('AIC2025.csv')
AIC2025
# Out:
# STT  | Blue team | Red team | BBan 1  | BBan 2  | BBan 3 | BBan 4 | B1      | B2      | B3      | B4     | B5      | Rban 1 | Rban 2 | Rban 3 | Rban 4 | R1      | R2      | R3      | R4     | R5      | Time  | Win
# 1    | 1S        | HKA      | enzo    | flo     | tara   | omen   | toro    | elandor | aya     | iggy   | nakarot | sines  | rouie  | ignis  | billow | teemee  | hayate  | mganga  | zephys | skurt   | 17:26 | HKA
# 2    | 1S        | HKA      | aya     | elandor | marja  | kerra  | anette  | billow  | ybnet   | stuart | airi    | rouie  | sines  | flo    | hayate | valhein | enzo    | tara    | raz    | rickter | 21:27 | 1S
# 3    | 1S        | HKA      | lorion  | billow  | aya    | flo    | elsu    | kerra   | gildur  | omen   | maloch  | rouie  | sines  | tarra  | thane  | violet  | toro    | nakarot | govera | yena    | 19:27 | 1S
# 4    | SPN       | FW       | valhein | capheny | zephys | mina   | mganga  | elandor | teemee  | airi   | kera    | sines  | rouie  | flo    | tachi  | hayate  | natalya | ybnet   | qi     | billow  | 9:03  | FW
# 5    | SPN       | FW       | valhein | lorion  | mganga | flo    | tara    | elsu    | enzo    | yena   | liliana | hayate | rouie  | aya    | billow | maloch  | sines   | stuart  | gildur | skurt   | 13:47 | FW
# 6    | ONE       | BAC      | billow  | lorion  | qi     | skurt  | valhein | thane   | mganga  | krinak | rickter | rouie  | sines  | mina   | zephys | enzo    | elandor | stuart  | iggy   | marja   | 7:22  | ONE
# 7    | ONE       | BAC      | valhein | hayate  | qi     | omen   | billow  | stuart  | maloch  | skurt  | ignis   | rouie  | sines  | flo    | govera | capheny | tara    | kera    | gildur | grakk   | 15:57 | ONE
# 8    | FPT       | BRU      | elandor | valhein | flo    | ignis  | hayate  | ybnet   | mganga  | tara   | marja   | sines  | rouie  | tachi  | mina   | teemee  | billow  | capheny | iggy   | rickter | 18:29 | BRU
# 9    | BRU       | FPT      | lorion  | elandor | ignis  | maloch | valhein | enzo    | mganga  | tachi  | airi    | sines  | rouie  | marja  | zephys | toro    | fennik  | kera    | iggy   | yena    | 24:15 | FPT
# 10   | FPT       | BRU      | hayate  | flo     | ybnet  | stuart | lorion  | teemee  | elandor | skurt  | elsu    | sines  | rouie  | qi     | wisp   | ignis   | marja   | mina    | fennik | toro    | 20:52 | FPT
# ... (87 rows omitted)

# %%
char_name = Table().with_columns(
    'Name', make_array(),
)
for i in order:
    temp = AIC2025.group(i)
    temp.relabel(i, 'Name')
    temp = temp.drop('count')
    char_name.append(temp)
char_name = char_name.group('Name').drop('count')
character = char_name.column('Name')
for i in character:
    print(i)
print(len(character))
# Out:
#  marja
# aduin
# airi
# anette
# ata
# aya
# azenka
# baldum
# billow
# biron
# butterfly
# capheny
# chalotte
# cresh
# dolia
# elandor
# elsu
# enzo
# fennik
# flo
# gildur
# govera
# goverra
# grakk
# hayate
# heino
# helen
# iggy
# iggy
# ignis
# kahlii
# kahlli
# kaine
# kera
# kerra
# kriknak
# krinak
# kriziz
# krizizz
# laville
# liliana
# lorion
# maloch
# marja
# mganga
# mina
# mina
# ming
# murad
# nakarot
# natalya
# omen
# qi
# raz
# rickter
# rouie
# ryoma
# sines
# skurt
# slimz
# stuart
# tachi
# tara
# tarra
# teemee
# telnat
# thane
# toro
# toro
# tulen
# valhein
# violet
# wiro
# wisp
# wonder woman
# yan
# ybnet
# yena
# yue
# zephys
# zip
# zuka
# 82

# %%
def replace_value_in_table(tbl, old_value, new_value):
    # Tạo một hàm phụ để áp dụng cho từng ô dữ liệu
    # Nếu gặp giá trị cũ thì đổi thành giá trị mới, ngược lại thì giữ nguyên
    def thay_the(x):
        return new_value if x == old_value else x

    # Tạo một bảng mới từ bảng gốc
    new_tbl = tbl

    # Duyệt qua từng cột trong bảng để cập nhật dữ liệu mới
    for lb in tbl.labels:
        # Dùng hàm .apply để biến đổi toàn bộ dữ liệu của cột 'lb'
        updated_column = new_tbl.apply(thay_the, lb)

        # Ghi đè cột đã sửa vào bảng mới
        new_tbl = new_tbl.with_column(lb, updated_column)

    return new_tbl

def remove_trailing_spaces(tbl):
    # Tạo bảng mới để lưu kết quả
    new_tbl = tbl

    # Định nghĩa một hàm phụ để xử lý từng ô dữ liệu
    def clean_cell(x):
        # Nếu ô đó là chuỗi chữ (string) thì mới cắt dấu cách,
        # nếu là số (int, float) thì giữ nguyên để tránh bị lỗi
        if isinstance(x, str):
            return x.rstrip()
        return x

    # Duyệt qua từng cột trong bảng để làm sạch
    for lb in tbl.labels:
        # Áp dụng hàm clean_cell cho toàn bộ cột 'lb'
        cleaned_column = new_tbl.apply(clean_cell, lb)

        # Ghi đè cột sạch vào bảng
        new_tbl = new_tbl.with_column(lb, cleaned_column)

    return new_tbl
AIC2025 = remove_trailing_spaces(AIC2025)
AIC2025
# Out:
# STT  | Blue team | Red team | BBan 1  | BBan 2  | BBan 3 | BBan 4 | B1      | B2      | B3      | B4     | B5      | Rban 1 | Rban 2 | Rban 3 | Rban 4 | R1      | R2      | R3      | R4     | R5      | Time  | Win
# 1    | 1S        | HKA      | enzo    | flo     | tara   | omen   | toro    | elandor | aya     | iggy   | nakarot | sines  | rouie  | ignis  | billow | teemee  | hayate  | mganga  | zephys | skurt   | 17:26 | HKA
# 2    | 1S        | HKA      | aya     | elandor | marja  | kerra  | anette  | billow  | ybnet   | stuart | airi    | rouie  | sines  | flo    | hayate | valhein | enzo    | tara    | raz    | rickter | 21:27 | 1S
# 3    | 1S        | HKA      | lorion  | billow  | aya    | flo    | elsu    | kerra   | gildur  | omen   | maloch  | rouie  | sines  | tarra  | thane  | violet  | toro    | nakarot | govera | yena    | 19:27 | 1S
# 4    | SPN       | FW       | valhein | capheny | zephys | mina   | mganga  | elandor | teemee  | airi   | kera    | sines  | rouie  | flo    | tachi  | hayate  | natalya | ybnet   | qi     | billow  | 9:03  | FW
# 5    | SPN       | FW       | valhein | lorion  | mganga | flo    | tara    | elsu    | enzo    | yena   | liliana | hayate | rouie  | aya    | billow | maloch  | sines   | stuart  | gildur | skurt   | 13:47 | FW
# 6    | ONE       | BAC      | billow  | lorion  | qi     | skurt  | valhein | thane   | mganga  | krinak | rickter | rouie  | sines  | mina   | zephys | enzo    | elandor | stuart  | iggy   | marja   | 7:22  | ONE
# 7    | ONE       | BAC      | valhein | hayate  | qi     | omen   | billow  | stuart  | maloch  | skurt  | ignis   | rouie  | sines  | flo    | govera | capheny | tara    | kera    | gildur | grakk   | 15:57 | ONE
# 8    | FPT       | BRU      | elandor | valhein | flo    | ignis  | hayate  | ybnet   | mganga  | tara   | marja   | sines  | rouie  | tachi  | mina   | teemee  | billow  | capheny | iggy   | rickter | 18:29 | BRU
# 9    | BRU       | FPT      | lorion  | elandor | ignis  | maloch | valhein | enzo    | mganga  | tachi  | airi    | sines  | rouie  | marja  | zephys | toro    | fennik  | kera    | iggy   | yena    | 24:15 | FPT
# 10   | FPT       | BRU      | hayate  | flo     | ybnet  | stuart | lorion  | teemee  | elandor | skurt  | elsu    | sines  | rouie  | qi     | wisp   | ignis   | marja   | mina    | fennik | toro    | 20:52 | FPT
# ... (87 rows omitted)

# %%
#clean data 1: filter the value
char_name = Table().with_columns(
    'Name', make_array(),
)
for i in order:
    temp = AIC2025.group(i)
    temp.relabel(i, 'Name')
    temp = temp.drop('count')
    char_name.append(temp)
char_name = char_name.group('Name').drop('count')
character = char_name.column('Name')
for i in character:
    print(i)
print(len(character))
#After filtering, copy every value into correction.txt, then do the fixing in correction.txt
# Out:
#  marja
# aduin
# airi
# anette
# ata
# aya
# azenka
# baldum
# billow
# biron
# butterfly
# capheny
# chalotte
# cresh
# dolia
# elandor
# elsu
# enzo
# fennik
# flo
# gildur
# govera
# goverra
# grakk
# hayate
# heino
# helen
# iggy
# ignis
# kahlii
# kahlli
# kaine
# kera
# kerra
# kriknak
# krinak
# kriziz
# krizizz
# laville
# liliana
# lorion
# maloch
# marja
# mganga
# mina
# ming
# murad
# nakarot
# natalya
# omen
# qi
# raz
# rickter
# rouie
# ryoma
# sines
# skurt
# slimz
# stuart
# tachi
# tara
# tarra
# teemee
# telnat
# thane
# toro
# tulen
# valhein
# violet
# wiro
# wisp
# wonder woman
# yan
# ybnet
# yena
# yue
# zephys
# zip
# zuka
# 79

# %%
fixed_array = make_array()
with open('correction.txt', 'r', encoding='utf-8') as f:
    fixed_array = f.readlines()
    fixed_array = [i.rstrip('\n') for i in fixed_array]
for i in fixed_array:
    a = i.split('|')
    AIC2025 = replace_value_in_table(AIC2025, a[0], a[1])
AIC2025
# Out:
# STT  | Blue team | Red team | BBan 1     | BBan 2     | BBan 3     | BBan 4     | B1      | B2         | B3         | B4      | B5       | Rban 1    | Rban 2    | Rban 3     | Rban 4  | R1      | R2         | R3       | R4      | R5      | Time  | Win
# 1    | 1S        | HKA      | Enzo       | Florentino | Taara      | Omen       | Toro    | Elland'orr | Aya        | Iggy    | Nak'roth | Sinestria | Rouie     | Ignis      | Billow  | Teemee  | Hayate     | Mganga   | Zephys  | Skud    | 17:26 | HKA
# 2    | 1S        | HKA      | Aya        | Elland'orr | Marja      | Keera      | Annette | Billow     | Y'bneth    | Stuart  | Airi     | Rouie     | Sinestria | Florentino | Hayate  | Valhein | Enzo       | Taara    | Raz     | Rickter | 21:27 | 1S
# 3    | 1S        | HKA      | Lorion     | Billow     | Aya        | Florentino | Elsu    | Keera      | Gildur     | Omen    | Maloch   | Rouie     | Sinestria | Taara      | Thane   | Violet  | Toro       | Nak'roth | Goverra | Yena    | 19:27 | 1S
# 4    | SPN       | FW       | Valhein    | Capheny    | Zephys     | Mina       | Mganga  | Elland'orr | Teemee     | Airi    | Keera    | Sinestria | Rouie     | Florentino | Tachi   | Hayate  | Natalya    | Y'bneth  | Qi      | Billow  | 9:03  | FW
# 5    | SPN       | FW       | Valhein    | Lorion     | Mganga     | Florentino | Taara   | Elsu       | Enzo       | Yena    | Liliana  | Hayate    | Rouie     | Aya        | Billow  | Maloch  | Sinestria  | Stuart   | Gildur  | Skud    | 13:47 | FW
# 6    | ONE       | BAC      | Billow     | Lorion     | Qi         | Skud       | Valhein | Thane      | Mganga     | Kriknak | Rickter  | Rouie     | Sinestria | Mina       | Zephys  | Enzo    | Elland'orr | Stuart   | Iggy    | Marja   | 7:22  | ONE
# 7    | ONE       | BAC      | Valhein    | Hayate     | Qi         | Omen       | Billow  | Stuart     | Maloch     | Skud    | Ignis    | Rouie     | Sinestria | Florentino | Goverra | Capheny | Taara      | Keera    | Gildur  | Grakk   | 15:57 | ONE
# 8    | FPT       | BRU      | Elland'orr | Valhein    | Florentino | Ignis      | Hayate  | Y'bneth    | Mganga     | Taara   | Marja    | Sinestria | Rouie     | Tachi      | Mina    | Teemee  | Billow     | Capheny  | Iggy    | Rickter | 18:29 | BRU
# 9    | BRU       | FPT      | Lorion     | Elland'orr | Ignis      | Maloch     | Valhein | Enzo       | Mganga     | Tachi   | Airi     | Sinestria | Rouie     | Marja      | Zephys  | Toro    | Fennik     | Keera    | Iggy    | Yena    | 24:15 | FPT
# 10   | FPT       | BRU      | Hayate     | Florentino | Y'bneth    | Stuart     | Lorion  | Teemee     | Elland'orr | Skud    | Elsu     | Sinestria | Rouie     | Qi         | Wisp    | Ignis   | Marja      | Mina     | Fennik  | Toro    | 20:52 | FPT
# ... (87 rows omitted)

# %%
def get_ban_statistic(tbl) :
    ans = Table().with_columns(
        'Name', make_array(),
        'count', make_array()
    )
    for label in tbl.labels:
        if 'Ban' in label or 'ban' in label:
            m = tbl.group(label)
            m.relabel(label, 'Name')
            ans.append(m)
    ans = ans.group('Name', sum)
    ans.relabel('count sum', 'count')
    ans = ans.sort('count', descending=True)
    return ans
ban_statistics = get_ban_statistic(AIC2025)
ban_statistics
# Out:
# Name       | count
# Rouie      | 86
# Sinestria  | 68
# Florentino | 61
# Valhein    | 44
# Elland'orr | 40
# Mganga     | 39
# Billow     | 36
# Marja      | 29
# Skud       | 27
# Hayate     | 24
# ... (41 rows omitted)

# %%
def get_pick_statistic(tbl) :
    ans = Table().with_columns(
        'Name', make_array(),
        'count', make_array()
    )
    for label in tbl.labels:
        if ('B' in label and 'Ban' not in label) or ('R' in label and 'ban' not in label):
            m = tbl.group(label)
            m.relabel(label, 'Name')
            ans.append(m)
    ans = ans.group('Name', sum)
    ans.relabel('count sum', 'count')
    ans = ans.sort('count', descending=True)
    return ans
pick_statistic = get_pick_statistic(AIC2025)
pick_statistic
# Out:
# Name    | count
# Billow  | 39
# Keera   | 39
# Hayate  | 36
# Mganga  | 36
# Skud    | 36
# Stuart  | 34
# Valhein | 34
# Toro    | 32
# Ignis   | 31
# Lorion  | 31
# ... (74 rows omitted)

# %%
def get_statistic(tbl) :
    ans = Table().with_columns(
        'Name', make_array(),
        'count', make_array()
    )
    for label in tbl.labels:
        m = tbl.group(label)
        m.relabel(label, 'Name')
        ans.append(m)
    ans = ans.group('Name', sum)
    ans.relabel('count sum', 'count')
    ans = ans.sort('count', descending=True)
    return ans
statistic = get_statistic(AIC2025)
statistic
# Out:
# Name       | count
# Rouie      | 96
# Sinestria  | 90
# Valhein    | 78
# Billow     | 75
# Mganga     | 75
# Florentino | 73
# Elland'orr | 69
# Skud       | 63
# Hayate     | 60
# Marja      | 57
# ... (264 rows omitted)

# %%
top5 = pick_statistic.take(np.arange(4))
top5list = top5.column(0)
top5list
# Out:
# array(['Billow', 'Keera', 'Hayate', 'Mganga'],
#       dtype='<U12')

# %%
for i in top5list:
    a = counter_statistic(AIC2025, i)
    a = a.take(np.arange(5))
    a.barh('Name')
    plt.savefig(i + '.png',bbox_inches='tight', dpi=300)
    plt.close()

# %%
def ally_statistic(tbl : Table, name) :
    ans = Table().with_columns(
        'Name', make_array(),
        'count', make_array()
    )
    for i in range(len(counter_slot)):
        a = counter_slot[i]
        temp_tbl = tbl.where(counter_slot[i], name)
        for j in range(i + 1, len(counter_slot)):
            b = counter_slot[j]
            if b[0] != a[0]:
                continue
            temp = temp_tbl.group(counter_slot[j])
            temp.relabel(counter_slot[j], 'Name')
            ans.append(temp)
        ans = ans.group('Name', sum)
        ans.relabel('count sum', 'count')
    ans = ans.sort('count', descending=True)
    return ans
c = ally_statistic(ac, 'Hayate')
c
# Out:
# Name    | count
# Murad   | 5
# Qi      | 4
# Airi    | 3
# Billow  | 3
# Toro    | 3
# Capheny | 2
# Iggy    | 2
# Keera   | 2
# Ryoma   | 2
# Skud    | 2
# ... (18 rows omitted)

# %%
for i in top5list:
    a = ally_statistic(AIC2025, i)
    a = a.take(np.arange(5))
    a.barh('Name')
    plt.savefig(i + '_ally.png',bbox_inches='tight', dpi=300)
    plt.close()

# %%
win = AIC2025.group('Win')
win.relabel('Win', 'Name')
win.barh('Name')
plt.savefig('win_statistic.png',bbox_inches='tight', dpi=300)
plt.show()
plt.close()

# %%
def all_to_second(time):
    a = time.split(':')
    return 60 * int(a[0]) + int(a[1])
a = AIC2025.apply(all_to_second, 'Time')
a = a / 60
time_mean = np.mean(a)
time_std = np.std(a)
AIC2025_with_second = AIC2025.with_column(
    'Second', a
)
bin_config = np.arange(52)
AIC2025_with_second.hist('Second', bins=bin_config)
plt.savefig('time.png',bbox_inches='tight', dpi=300)
plt.show()
plt.close()
print(time_mean, time_std)
# Out:
# 17.591580756 6.93126254585
